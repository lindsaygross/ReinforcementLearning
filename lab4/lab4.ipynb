# %% [markdown]
# <a href="https://colab.research.google.com/github/lindsaygross/ReinforcementLearning/blob/main/lab4/lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4
# ## CartPole with Value-Based Agents (DQN Variants)
#
# Objectives:
# 1. Train a **baseline DQN** on CartPole using **RL Zoo 3** (a training harness around Stable-Baselines3).
# 2. Diagnose **stability** by inspecting learning curves and evaluation performance.
# 3. Implement and train **Dueling DQN** (an architecture change) using Stable-Baselines3 directly.
# 4. On your own, implemnet **Double DQN**

# %% [markdown]
# Run on Google Colab:
#
# [![Open In Collab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duke-trust-lab/intro_modern_rl/blob/main/lab4/lab4.ipynb)

# %%
# %pip install -q stable-baselines3==2.* sb3-contrib==2.* gymnasium matplotlib pandas pyyaml imageio ffmpeg-python
# %pip install -q rl_zoo3

# %%
import os
import glob
import time
import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from IPython.display import Video, display

import gymnasium as gym
import torch

# %% [markdown]
# ### What DQN is doing
#
# DQN learns an approximation of the action-value function:
#
# Qθ(s,a)
#
# A standard DQN target is:
#
# y = r + γ max_a' Qθ⁻(s', a')
#
# where:
# - θ: online network parameters (updated every gradient step)
# - θ⁻: target network parameters (updated more slowly)
#
# DQN typically uses:
# - **experience replay**: sample random mini-batches from a replay buffer (reduces correlation)
# - **target network**: stabilizes the moving target in TD learning
# - **ε-greedy exploration**: balance exploration vs exploitation

# %% [markdown]
# ---
#
# ## Why use RL Zoo 3 for the baseline run?
#
# RL Zoo provides:
# - a clean, repeatable CLI training workflow
# - standardized logging + saved best models
# - video recording utilities
#
# This lets us focus on:
# - what the hyperparameters mean
# - what the training curves tell us
# - how evaluation differs from training

# %% [markdown]
# ### Create RL Zoo YAML config for baseline DQN

# %%
ENV_ID = "CartPole-v1"
LOG_DIR = "logs"

os.makedirs(LOG_DIR, exist_ok=True)

dqn_config = {
    ENV_ID: {
        "policy": "MlpPolicy",
        "n_timesteps": float(6e4),
        "buffer_size": 20000,
        "learning_starts": 1000,
        "target_update_interval": 250,
        "exploration_fraction": 0.2,
        "exploration_final_eps": 0.06,
        "learning_rate": float(1e-3),
        "batch_size": 64,
        "train_freq": 32,
        "gradient_steps": 16,
        "gamma": 0.99,
        "optimize_memory_usage": False,
    }
}

with open("dqn_base.yaml", "w") as f:
    yaml.safe_dump(dqn_config, f, sort_keys=False)

print("Wrote dqn_base.yaml")
# Out:
# Wrote dqn_base.yaml

# %%
# Train a single baseline run (seed 0). You can later expand to multiple seeds.
seed = 0
cmd = f"python -m rl_zoo3.train --algo dqn --env {ENV_ID} -f {LOG_DIR}/ -c dqn_base.yaml --log-interval 1000 --seed {seed}"
print("Running:", cmd)
# !{cmd}
# Out:
# Running: python -m rl_zoo3.train --algo dqn --env CartPole-v1 -f logs/ -c dqn_base.yaml --log-interval 1000 --seed 0
# 2026-02-03 23:52:23.420322: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770162743.469417    5940 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770162743.480133    5940 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770162743.506816    5940 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770162743.506874    5940 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770162743.506882    5940 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770162743.506888    5940 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# ========== CartPole-v1 ==========
# Seed: 0
# Loading hyperparameters from: dqn_base.yaml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 64),
#              ('buffer_size', 20000),
#              ('exploration_final_eps', 0.06),
#              ('exploration_fraction', 0.2),
#              ('gamma', 0.99),
#              ('gradient_steps', 16),
#              ('learning_rate', 0.001),
#              ('learning_starts', 1000),
#              ('n_timesteps', 60000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'MlpPolicy'),
#              ('target_update_interval', 250),
#              ('train_freq', 32)])
# Using 1 environments
# Creating test environment
# Using cuda device
# Log path: logs//dqn/CartPole-v1_2
# Eval num_timesteps=25000, episode_reward=126.80 +/- 3.43
# Episode length: 126.80 +/- 3.43
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 127      |
# |    mean_reward      | 127      |
# | rollout/            |          |
# |    exploration_rate | 0.06     |
# | time/               |          |
# |    total_timesteps  | 25000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.227    |
# |    n_updates        | 12000    |
# ----------------------------------
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=336.80 +/- 7.86
# Episode length: 336.80 +/- 7.86
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 337      |
# |    mean_reward      | 337      |
# | rollout/            |          |
# |    exploration_rate | 0.06     |
# | time/               |          |
# |    total_timesteps  | 50000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.235    |
# |    n_updates        | 24496    |
# ----------------------------------
# New best mean reward!
# Saving to logs//dqn/CartPole-v1_2

# %%
cmd = f"""python -m rl_zoo3.record_video \
  --algo dqn \
  --env {ENV_ID} \
  --folder {LOG_DIR}/ \
  -n 600 \
  --deterministic \
  --load-best
"""
print("Running:", cmd)
# !{cmd}
# Out:
# Running: python -m rl_zoo3.record_video   --algo dqn   --env CartPole-v1   --folder logs/   -n 600   --deterministic   --load-best
#
# 2026-02-03 23:54:36.460213: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770162876.523576    6541 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770162876.551066    6541 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770162876.612668    6541 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770162876.612712    6541 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770162876.612720    6541 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770162876.612728    6541 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=2
# Loading logs/dqn/CartPole-v1_2/best_model.zip
# Loading logs/dqn/CartPole-v1_2/best_model.zip
# /usr/local/lib/python3.12/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# error: XDG_RUNTIME_DIR not set in the environment.
# Saving video to /content/logs/dqn/CartPole-v1_2/videos/best-model-dqn-CartPole-v1-step-0-to-step-600.mp4
# Moviepy - Building video /content/logs/dqn/CartPole-v1_2/videos/best-model-dqn-CartPole-v1-step-0-to-step-600.mp4.
# Moviepy - Writing video /content/logs/dqn/CartPole-v1_2/videos/best-model-dqn-CartPole-v1-step-0-to-step-600.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/logs/dqn/CartPole-v1_2/videos/best-model-dqn-CartPole-v1-step-0-to-step-600.mp4

# %%
mp4s = glob.glob(os.path.join(LOG_DIR, "**", "*.mp4"), recursive=True)
mp4s_sorted = sorted(mp4s, key=os.path.getmtime, reverse=True)
print("Found videos:", len(mp4s_sorted))

if mp4s_sorted:
    print("Showing:", mp4s_sorted[0])
    display(Video(mp4s_sorted[0], embed=True))
# Out:
# Found videos: 2
# Showing: logs/dqn/CartPole-v1_2/videos/best-model-dqn-CartPole-v1-step-0-to-step-600.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Diagnosing value estimation instability
#
# In deep value-based RL, instability can show up as:
# - learning curves that spike then collapse
# - large oscillations in evaluation returns
# - sensitivity to seed / hyperparameters
# - apparently “good” training signals that don’t transfer to evaluation behavior

# %% [markdown]
# ### Dueling DQN
#
# Dueling DQN explicitly decomposes:
#
# Q(s,a) = V(s) + A(s,a) − mean_a A(s,a)
#
# Intuition:
# - V(s): how good is the state (regardless of action)?
# - A(s,a): how much better is action a compared to other actions in state s?
#
# This can help in environments where:
# - many actions have similar value
# - learning V(s) is easier than learning full Q(s,a) directly
#
# We will implement a custom DQN policy with dueling heads.

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import EvalCallback

SB3_LOG_BASE = "sb3_logs"
os.makedirs(SB3_LOG_BASE, exist_ok=True)

def make_env(env_id="CartPole-v1"):
    env = gym.make(env_id)
    env = Monitor(env)
    return env

def train_sb3(
    name: str,
    policy,
    env_id="CartPole-v1",
    total_timesteps=60_000,
    seed=0,
    policy_kwargs=None,
):
    env = make_env(env_id)
    eval_env = make_env(env_id)

    run_dir = os.path.join(SB3_LOG_BASE, name)
    os.makedirs(run_dir, exist_ok=True)

    eval_callback = EvalCallback(
        eval_env,
        best_model_save_path=run_dir,
        log_path=run_dir,
        eval_freq=10_000,
        deterministic=True,
        render=False,
    )

    model = DQN(
        policy,
        env,
        learning_rate=1e-3,
        buffer_size=20_000,
        learning_starts=1_000,
        batch_size=64,
        tau=1.0,                  # hard target updates
        target_update_interval=250,
        train_freq=32,
        gradient_steps=16,
        gamma=0.99,
        exploration_fraction=0.2,
        exploration_final_eps=0.06,
        policy_kwargs=policy_kwargs,
        verbose=0,
        seed=seed,
        device="cuda" if torch.cuda.is_available() else "cpu",
    )

    model.learn(total_timesteps=total_timesteps, callback=eval_callback)
    model.save(os.path.join(run_dir, "final_model"))
    return run_dir

# %% [markdown]
# ### Define Dueling DQN policy

# %%
import torch.nn as nn
from stable_baselines3.dqn.policies import DQNPolicy, QNetwork

class DuelingQNetwork(QNetwork):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

        hidden_dim = 256

        self.shared = nn.Sequential(
            nn.Linear(self.features_dim, hidden_dim),
            nn.ReLU(),
        )

        # Value head V(s)
        self.V = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1),
        )

        # Advantage head A(s,a)
        self.A = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, self.action_space.n),
        )

    def forward(self, obs):
        features = self.extract_features(obs, self.features_extractor)
        h = self.shared(features)
        v = self.V(h)                          # [batch, 1]
        a = self.A(h)                          # [batch, n_actions]
        q = v + (a - a.mean(dim=1, keepdim=True))
        return q

class DuelingDQNPolicy(DQNPolicy):
    def make_q_net(self):
        net_args = self._update_features_extractor(self.net_args, features_extractor=None)
        return DuelingQNetwork(**net_args).to(self.device)

# %% [markdown]
# ### Train baseline SB3 DQN + Dueling DQN

# %%
seed = 0
sb3_baseline_dir = train_sb3("dqn_baseline_seed0", policy="MlpPolicy", seed=seed)
sb3_dueling_dir  = train_sb3("dqn_dueling_seed0",  policy=DuelingDQNPolicy, seed=seed)

sb3_baseline_dir, sb3_dueling_dir
# Out:
# Eval num_timesteps=10000, episode_reward=207.40 +/- 80.73
# Episode length: 207.40 +/- 80.73
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=111.00 +/- 2.28
# Episode length: 111.00 +/- 2.28
# Eval num_timesteps=30000, episode_reward=123.00 +/- 1.67
# Episode length: 123.00 +/- 1.67
# Eval num_timesteps=40000, episode_reward=287.80 +/- 2.64
# Episode length: 287.80 +/- 2.64
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=338.20 +/- 8.06
# Episode length: 338.20 +/- 8.06
# New best mean reward!
# Eval num_timesteps=60000, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=10000, episode_reward=120.60 +/- 1.96
# Episode length: 120.60 +/- 1.96
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=90.80 +/- 1.94
# Episode length: 90.80 +/- 1.94
# Eval num_timesteps=30000, episode_reward=164.40 +/- 7.63
# Episode length: 164.40 +/- 7.63
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=99.80 +/- 4.26
# Episode length: 99.80 +/- 4.26
# Eval num_timesteps=50000, episode_reward=129.40 +/- 2.87
# Episode length: 129.40 +/- 2.87
# Eval num_timesteps=60000, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# ('sb3_logs/dqn_baseline_seed0', 'sb3_logs/dqn_dueling_seed0')

# %% [markdown]
# ### SB3 eval curves

# %%
def load_eval_npz(run_dir):
    npz_path = os.path.join(run_dir, "evaluations.npz")
    if not os.path.exists(npz_path):
        return None
    data = np.load(npz_path)
    timesteps = data["timesteps"]
    results = data["results"]          # shape [n_evals, n_episodes]
    mean_reward = results.mean(axis=1)
    return pd.DataFrame({"timesteps": timesteps, "mean_reward": mean_reward})

b = load_eval_npz(sb3_baseline_dir)
d = load_eval_npz(sb3_dueling_dir)

plt.figure()
if b is not None:
    plt.plot(b["timesteps"], b["mean_reward"], label="SB3 DQN baseline")
if d is not None:
    plt.plot(d["timesteps"], d["mean_reward"], label="SB3 Dueling DQN")
plt.xlabel("timesteps")
plt.ylabel("eval mean reward")
plt.title("Evaluation Performance: Baseline vs Dueling")
plt.legend()
plt.show()

# %%
import os
import imageio
import gymnasium as gym
import numpy as np

from stable_baselines3 import DQN

def record_sb3_rollout_mp4(
    model_zip_path: str,
    out_mp4_path: str,
    env_id: str = "CartPole-v1",
    n_steps: int = 600,          # 600 frames at 30 fps = 20 seconds
    fps: int = 30,
    deterministic: bool = True,
):
    os.makedirs(os.path.dirname(out_mp4_path), exist_ok=True)

    env = gym.make(env_id, render_mode="rgb_array")
    model = DQN.load(model_zip_path)

    obs, info = env.reset()
    frames = []

    for _ in range(n_steps):
        frame = env.render()
        frames.append(frame)

        action, _ = model.predict(obs, deterministic=deterministic)
        obs, reward, terminated, truncated, info = env.step(action)

        if terminated or truncated:
            obs, info = env.reset()

    env.close()

    imageio.mimsave(out_mp4_path, frames, fps=fps)
    return out_mp4_path

# %%
baseline_mp4 = record_sb3_rollout_mp4(
    model_zip_path=os.path.join(sb3_baseline_dir, "best_model.zip"),
    out_mp4_path=os.path.join(sb3_baseline_dir, "videos_manual", "baseline.mp4"),
    n_steps=600,
    fps=30,
)

dueling_mp4 = record_sb3_rollout_mp4(
    model_zip_path=os.path.join(sb3_dueling_dir, "best_model.zip"),
    out_mp4_path=os.path.join(sb3_dueling_dir, "videos_manual", "dueling.mp4"),
    n_steps=600,
    fps=30,
)

baseline_mp4, dueling_mp4
# Out:
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ('sb3_logs/dqn_baseline_seed0/videos_manual/baseline.mp4',
#  'sb3_logs/dqn_dueling_seed0/videos_manual/dueling.mp4')

# %%
from IPython.display import Video, display

display(Video(baseline_mp4, embed=True))
display(Video(dueling_mp4, embed=True))
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ### Double DQN
#
# A common failure mode in value-based RL is **overestimation bias**.
#
# Why?
# - Q-values are learned estimates and are noisy.
# - Taking `max_a Q(s,a)` tends to select actions with positive noise.
#
# Baseline DQN target:
# y = r + γ max_a' Qθ⁻(s', a')
#
# Double DQN target (key idea: decouple selection and evaluation):
# 1) select action using online net:
#    a* = argmax_a' Qθ(s', a')
#
# 2) evaluate that action using target net:
#    y = r + γ Qθ⁻(s', a*)
#
# This reduces maximization bias and often improves stability.

# %% [markdown]
# ### TODO
# - Implement Double DQN
# - Plot evaluation of Baseline v. Dueling v. Double DQN

# %%
seed = 0
sb3_double_dir = train_sb3("dqn_double_seed0", policy="MlpPolicy", seed=seed)
sb3_double_dir
# Out:
# Eval num_timesteps=10000, episode_reward=166.40 +/- 23.38
# Episode length: 166.40 +/- 23.38
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=115.40 +/- 2.58
# Episode length: 115.40 +/- 2.58
# Eval num_timesteps=30000, episode_reward=121.00 +/- 2.10
# Episode length: 121.00 +/- 2.10
# Eval num_timesteps=40000, episode_reward=335.00 +/- 82.75
# Episode length: 335.00 +/- 82.75
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=337.40 +/- 12.03
# Episode length: 337.40 +/- 12.03
# New best mean reward!
# Eval num_timesteps=60000, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# 'sb3_logs/dqn_double_seed0'

# %%
dd = load_eval_npz(sb3_double_dir)
dd.head()
# Out:
#    timesteps  mean_reward
# 0      10000        166.4
# 1      20000        115.4
# 2      30000        121.0
# 3      40000        335.0
# 4      50000        337.4
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
plt.figure(figsize=(10, 6))
if b is not None:
    plt.plot(b["timesteps"], b["mean_reward"], label="SB3 DQN baseline")
if d is not None:
    plt.plot(d["timesteps"], d["mean_reward"], label="SB3 Dueling DQN")
if dd is not None:
    plt.plot(dd["timesteps"], dd["mean_reward"], label="SB3 Double DQN")
plt.xlabel("Timesteps")
plt.ylabel("Evaluation Mean Reward")
plt.title("Evaluation Performance: Baseline vs Dueling vs Double DQN")
plt.legend()
plt.grid(True)
plt.show()

# %%
double_dqn_mp4 = record_sb3_rollout_mp4(
    model_zip_path=os.path.join(sb3_double_dir, "best_model.zip"),
    out_mp4_path=os.path.join(sb3_double_dir, "videos_manual", "double_dqn.mp4"),
    n_steps=600,
    fps=30,
)

print(f"Recorded Double DQN video: {double_dqn_mp4}")
# Out:
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Recorded Double DQN video: sb3_logs/dqn_double_seed0/videos_manual/double_dqn.mp4

# %%
display(Video(double_dqn_mp4, embed=True))
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
